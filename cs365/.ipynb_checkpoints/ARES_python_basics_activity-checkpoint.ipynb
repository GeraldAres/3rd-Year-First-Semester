# %% [markdown]
# # CSIT 349 -- Python Basics Lab
# **Lecture coverage:** `python1.ppt` slides 1-28 (stop before *Mutability: Tuples vs. Lists*)
#
# **Time:** about 30-40 minutes
# **What this lab checks:** basic Python syntax and the three sequence types (strings, lists, tuples)
#
# ---
#
# ### How to complete this activity
# 1. Put your name in the next cell, then run cells **from top to bottom**.
# 2. Read the short notes in each part (they match the lecture).
# 3. Replace every `# TODO` with working Python 3 code.
# 4. When a cell asks you to **predict** an answer, write the prediction in a comment *before* you run it.
# 5. Do **not** use list methods that change a list in place (`append`, `insert`, `sort`, ...). Those start on the mutability slides.
#
# **Python 3 reminder:** the slides were written for an older Python. In Python 3:
# - `print` is a function: `print(x)`
# - `/` is true division (`5 / 2` is `2.5`)
# - `//` is integer (floor) division (`5 // 2` is `2`)

# %%
# TODO: fill these in, then run this cell
student_name = "Gerald Benedict S. Ares"
section = "F1"
print("Notebook submitted by:", student_name, "|", section)

# %% [markdown]
# ## Part A -- A first look at Python (slides 1-8)
#
# Python was created by **Guido van Rossum**. Code meaning depends on **indentation**. The first assignment to a name creates it; you do not declare types. Use `=` for assignment and `==` for comparison. Arithmetic `+ - * / %` work as usual; `+` also concatenates strings. Logical operators are the words `and`, `or`, `not`.

# %% [markdown]
# ### Problem 1 -- Recreate the lecture sample
#
# Write a small program that does the same work as the IDLE example on the slides:
#
# - Start with `x = 34 - 23`, `y = "Hello"`, and `z = 3.45`
# - If `z` equals `3.45` **or** `y` equals `"Hello"`, add `1` to `x` and concatenate `" World"` onto `y`
# - Print both `x` and `y`
#
# Expected output:
# ```
# 12
# Hello World
# ```

# %%
# Problem 1
# TODO: write the program here
x = 34 - 23
y = "Hello"
z = 3.45
newWord = " World"
if z == 3.45 and y == "Hello":
    x += 1
    print(x)
    print(y + newWord) 
else:
    print("Wrong")
# Out:
# 12
# Hello World

# %% [markdown]
# ### Problem 2 -- Indentation is meaning
#
# The cell below is **broken** because the block under `if` is not indented. Fix **only the indentation** so it prints `inside` and then `after`. Do not change the logic.

# %%
# Problem 2 -- fix the indentation
flag = True
if flag:
    print("inside")
    print("after")
# Out:
# inside
# after

# %% [markdown]
# ### Problem 3 -- Operators and logic
#
# Complete the expressions so each `print` shows the value in the comment on that line.

# %%
# Problem 3
# TODO: replace the zeros / False with the correct expressions

score = 82
late = False

remainder = 17 % 5          # 17 divided by 5, remainder  ->  2
greeting = "CSIT"          # concatenate "CSIT" and " 349"  ->  CSIT 349
is_pass = score >= 75 and late is False        # True if score is at least 75 AND late is False

if score >= 75:
    print(remainder)   # 2
    print(greeting + " 349")    # CSIT 349
    print(is_pass)     # True
else:
    print(remainder)   # 2
    print(greeting)    # CSIT 349
    print(is_pass)     # True
# Out:
# 2
# CSIT 349
# True

# %% [markdown]
# ## Part B -- Types, whitespace, comments (slides 9-11)
#
# **Integers** and **floats** are the basic number types. **Strings** can use `'single'`, `"double"`, or triple quotes. Triple quotes are good for multi-line text and for strings that contain both `'` and `"`.
#
# Comments start with `#`. A **docstring** is a string placed as the first line of a function; tools and `help()` can read it.

# %% [markdown]
# ### Problem 4 -- Know your types
#
# For each value, print its type using `type(...)`. Then write one string that contains an apostrophe (like `matt's`) using **double quotes**, and one multi-line string using **triple quotes**.

# %%
# Problem 4
n = 11
x = 3.456
word = "abc"

# TODO: print the type of n, x, and word

# TODO: assign a string with an apostrophe to `possessive` using double quotes
possessive = "George's"

# TODO: assign a 2-line string to `blurb` using triple quotes
blurb = "Passar Automata"

print(possessive)
print(blurb)
# Out:
# George's
# Passar Automata

# %% [markdown]
# ### Problem 5 -- Comments and a docstring
#
# 1. Add a `#` comment that explains what the function returns.
# 2. Put a **docstring** inside `area` (first line of the function body).
# 3. Return `length * width`.

# %%
# Problem 5
def area(length, width):
    # TODO: docstring here
    # TODO: return the area
    """The Length and Area of this shape."""
    return length * width

print(area(4, 2.5))   # should print 10.0
print(area.__doc__)   # should print your docstring
# Out:
# 10.0
# The Length and Area of this Shape

# %% [markdown]
# ## Part C -- Names and assignment (slides 12-16)
#
# - Assignment binds a **name** to an **object**. Names have no type; objects do.
# - Valid names: letters, digits, underscores; **cannot start with a digit**; case-sensitive (`bob` is not `Bob`).
# - Multiple assignment: `x, y = 2, 3` and swap with `x, y = y, x`
# - Chained assignment: `a = b = x = 2`
# - Using a name before it is assigned raises `NameError`

# %% [markdown]
# ### Problem 6 -- Which names are legal?
#
# Uncomment **only the legal** assignments. Leave illegal ones commented out. Then print `bob`, `Bob`, and `_2_bob_`.

# %%
# Problem 6
# Uncomment the legal ones only:

bob = 1
Bob = 2
# 2bob = 3
_2_bob_ = 4
# bob-2 = 5
# class = 6

# TODO: print bob, Bob, and _2_bob_
print(bob)
print(Bob)
print(_2_bob_)
# Out:
# 1
# 2
# 4

# %% [markdown]
# ### Problem 7 -- Unpack, swap, chain
#
# Follow the comments. Do not hard-code the final numbers except in the first assignment.

# %%
# Problem 7
# TODO: assign 2 to x and 3 to y in ONE line
x, y = 2, 3
# TODO: swap x and y in ONE line (should become x=3, y=2)
x, y = y, x
# TODO: make a, b, and c all refer to 10 using chained assignment
a = b = c = 10

print(x, y)       # 3 2
print(a, b, c)    # 10 10 10
# Out:
# 3 2
# 10 10 10

# %% [markdown]
# ### Problem 8 -- NameError
#
# Run this cell **as-is** first and read the error. Then fix it by assigning `course` before it is used.

# %%
# Problem 8
# TODO: create the name course, then print it
course = "CS365"
print(course)
# Out:
# CS365

# %% [markdown]
# ## Part D -- Sequence types (slides 17-28)
#
# Three sequence types share the same access syntax:
#
# | Type | Example | Mutable? |
# |------|---------|----------|
# | **tuple** | `("john", 32, ["CMSC"])` | no |
# | **string** | `"John Smith"` | no |
# | **list** | `[1, 2, "john", ("up", "down")]` | yes |
#
# Items can be mixed types. Indexing is **0-based**. Negative indices count from the right (`-1` is the last item).
#
# **Slicing** `seq[start:stop]` copies from `start` up to **but not including** `stop`.
# - `t[:2]` -- from the beginning
# - `t[2:]` -- through the end
# - `t[:]` -- a copy of the whole sequence
#
# `in` tests membership (`"cd" in "abcde"` is `True`, but `"ac" in "abcde"` is `False`).
# `+` concatenates. `*` repeats.

# %% [markdown]
# ### Problem 9 -- Build the three sequences
#
# Create the sequences described below. Use parentheses for the tuple, square brackets for the list, and quotes for the string.

# %%
# Problem 9
# TODO: tuple with 23, "abc", 4.56, the tuple (2, 3), and "def"
tu = (23, "abc", 4.56, (2, 3), "def")

# TODO: list with "abc", 34, 4.34, and 23
li = ["abc", 34, 4.34, 23]

# TODO: string Hello World
st = "Hello World"

print(tu)
print(li)
print(st)
print(type(tu), type(li), type(st))
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')
# ['abc', 34, 4.34, 23]
# Hello World
# <class 'tuple'> <class 'list'> <class 'str'>

# %% [markdown]
# ### Problem 10 -- Indexing
#
# Using **only indexing** (no loops), print what the comments ask for.
#
# Given `t = (23, "abc", 4.56, (2, 3), "def")`:
# - index `1` is `"abc"`
# - index `-3` is `4.56`

# %%
# Problem 10
t = (23, "abc", 4.56, (2, 3), "def")
st = "Hello World"
li = ["abc", 34, 4.34, 23]

# TODO: second item of t   ("abc")
print(t[1])
# TODO: last item of t     ("def")  -- use a negative index
print(t[-1])
# TODO: nested 3 from (2, 3)
print(t[3][1])
# TODO: second character of st  ("e")
print(st[1])
# TODO: last item of li    (23)
print(li[3])
# Out:
# abc
# def
# 3
# e
# 23

# %% [markdown]
# ### Problem 11 -- Slicing
#
# Work with the same tuple. Write a prediction in a comment, then fill in the slice.
#
# Remember: the stop index is **excluded**.

# %%
# Problem 11
t = (23, "abc", 4.56, (2, 3), "def")

# TODO: items from index 1 up to (not including) 4
# prediction:
slice_a = t[1:4]

# TODO: drop the first and last items  (use a negative stop index)
# prediction:
slice_b = t[1:4]

# TODO: the first two items
slice_c = t[0:2]

# TODO: everything from index 2 to the end
slice_d = t[2:5]

print(slice_a)  # ("abc", 4.56, (2, 3))
print(slice_b)  # ("abc", 4.56, (2, 3))
print(slice_c)  # (23, "abc")
print(slice_d)  # (4.56, (2, 3), "def")
# Out:
# ('abc', 4.56, (2, 3))
# ('abc', 4.56, (2, 3))
# (23, 'abc')
# (4.56, (2, 3), 'def')

# %% [markdown]
# ### Problem 12 -- Copy vs two names for one list
#
# `l2 = l1` makes two names for the **same** list.
# `l3 = l1[:]` makes an **independent copy**.
#
# You will see this again with mutability. For now, just confirm the idea with `id(...)` (the identity of the object in memory).

# %%
# Problem 12
l1 = [10, 20, 30]
l2 = l1
l3 = l1[:]

print("l1 is l2?", l1 is l2)   # True: same object
print("l1 is l3?", l1 is l3)   # False: different object

print(id(l1), id(l2), id(l3))

# TODO: predict these two Booleans, then print them
same_content_copy = (l1 == l3)   # True or False?
same_object_copy = (l1 is l3)    # True or False?
print(same_content_copy)
print(same_object_copy)
# Out:
# l1 is l2? True
# l1 is l3? False
# 1479434630592 1479434630592 1479434582272
# True
# False

# %% [markdown]
# ### Problem 13 -- `in`, `+`, and `*`
#
# Complete each assignment. For strings, `in` checks **substrings**.

# %%
# Problem 13
nums = [1, 2, 4, 5]
letters = "abcde"

# TODO: True if 4 is in nums
has_four = 4 in nums

# TODO: True if 3 is NOT in nums
no_three = 3 not in nums

# TODO: True if "cd" is a substring of letters
has_cd = "cd" in letters

# TODO: True if "ac" is a substring of letters  (careful)
has_ac = "ac" in letters

# TODO: concatenate (1, 2, 3) and (4, 5, 6)
joined_tu =  (1, 2, 3) + (4, 5, 6)

# TODO: concatenate [1, 2, 3] and [4, 5, 6]
joined_li = [1, 2, 3] + [4, 5, 6]

# TODO: "Hello" + space + "World"
joined_st = "Hello" + " " + "World"

# TODO: repeat [1, 2, 3] three times
repeated = [1, 2, 3] * 3

# TODO: repeat "Hi" three times
chant = "Hi"


print(has_four, no_three)     # True True
print(has_cd, has_ac)         # True False
print(joined_tu)
print(joined_li)
print(joined_st)              # Hello World
print(repeated)
for num in range(3):
    print(chant, end ="")                  # HiHiHi
# Out:
# True True
# True False
# (1, 2, 3, 4, 5, 6)
# [1, 2, 3, 4, 5, 6]
# Hello World
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# HiHiHi

# %% [markdown]
# ## Part E -- Mini challenge (mix of syntax + sequences)
#
# A student record is stored as a **tuple** `(name, id_number, scores)` where `scores` is a **list** of three quiz grades.
#
# Using only the ideas from slides 1-28 (indexing, slicing, `in`, `+`, `*`, assignment, `and`/`or`):
#
# 1. Print the student's name and id.
# 2. Print the first two quiz scores (a slice).
# 3. Print whether quiz `90` appears in `scores`.
# 4. Build the display string `Name: <name>` using concatenation.
# 5. Print a separator line of 12 dashes using `*`.

# %%
# Problem 14 -- mini challenge
record = ("Ada", 20261001, [88, 90, 79])

# TODO: unpack or index to get name, student_id, scores
name = record[0]
student_id = record[1]
# TODO: print name and student_id
print("Name:", name ,"\nStudent_id:", student_id)
# TODO: print the first two scores (slice)
print("First two scores:", record[2][0:2])

# TODO: print whether 90 is in scores
validate = 90 in record[2]
print("90 Exist (T/F):", validate)

# TODO: print "Name: Ada" using +
print("Name: " + name)

# TODO: print 12 dashes using *
print("-"*12)
# Out:
# Name: Ada
# Student_id: 20261001
# First two scores: [88, 90]
# 90 Exist (T/F): True
# Name: Ada
# ------------

# %% [markdown]
# ## Done -- quick self-check
#
# You should now be able to:
#
# - [ ] Write a short program with assignment, `if`, `and`/`or`, and `print`
# - [ ] Use indentation to mark a block
# - [ ] Choose `int` / `float` / `str` and write comments or a docstring
# - [ ] Create legal names; unpack and swap values
# - [ ] Build a tuple, a list, and a string
# - [ ] Index (including negatives) and slice with the stop index excluded
# - [ ] Use `in`, `+`, and `*` on sequences
# - [ ] Explain why `l2 = l1` is not the same as `l2 = l1[:]`
#
# **Next lecture:** Mutability -- Tuples vs. Lists (slide 29 onward).
